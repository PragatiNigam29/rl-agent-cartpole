# %%
import gymnasium as gym
from stable_baselines3 import PPO

# Create environment
env = gym.make("CartPole-v1")

# Create the PPO model
model = PPO("MlpPolicy", env, verbose=1)

# Train the model
model.learn(total_timesteps=10000)

# Save the model
model.save("ppo_cartpole_model")

# Test the model
obs, _ = env.reset()
for _ in range(1000):
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    env.render()
    if terminated or truncated:
        obs, _ = env.reset()

env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | 21.9     |
# | time/              |          |
# |    fps             | 1565     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.1        |
# |    ep_rew_mean          | 26.1        |
# | time/                   |             |
# |    fps                  | 1037        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008660672 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00445     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.95        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 48.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.6        |
# |    ep_rew_mean          | 35.6        |
# | time/                   |             |
# |    fps                  | 981         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008744042 |
# |    clip_fraction        | 0.0686      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.093       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 36.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.9         |
# |    ep_rew_mean          | 47.9         |
# | time/                   |              |
# |    fps                  | 922          |
# |    iterations           | 4            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0068191197 |
# |    clip_fraction        | 0.0643       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.641       |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.9         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0173      |
# |    value_loss           | 55.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 62.6       |
# |    ep_rew_mean          | 62.6       |
# | time/                   |            |
# |    fps                  | 898        |
# |    iterations           | 5          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01078248 |
# |    clip_fraction        | 0.0856     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.615     |
# |    explained_variance   | 0.39       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 29         |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0156    |
# |    value_loss           | 60.9       |
# ----------------------------------------
# C:\Users\acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:250: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(
